# %% [markdown]
# ## Visão Computacional: Análise de Imagens Médicas
#
# ## 1. Introdução
#
# As tecnologias de imagens médicas estão cada vez mais integradas aos sitemas de visão computacional, incluindo as imagens de raio-x.
#
# Modelos de equipamentos modernos geram imagens digitais deste tipo de exame, proporcionando análises mais completas e menos _ad-hoc_, com isso algumas pré-análises podem ser realizadas por aplicações baseadas em inteligência artificial para confirmar ou sugerir diagnósticos ao profissional responsável pelo exame.
#
# No campo dos diagósticos por raios-x, a pnenumonia é uma das enfermidades onde seu uso é um dos mais aplicados para determinar o curso de tratamento.
#
# <p align="center">
#     <img src="imagens/NORMAL2-IM-1422-0001.jpeg">
# </p>
#
# ## 2. Instruções
#
# Este projeto final tem como objetivo explorar os conhecimentos adquiridos nas aulas práticas.
#
# Por meio de uma trilha guiada, iremos constuir um modelo que seja capaz de classificar imagens de raio-x para determinar se a determinada pessoa está com alguma condição que necessita maiores cuidados.
#
# De acordo com as imagens disponíveis para o treinamento e validação, será de critério do grupo selecionar as quantidades ideais ou até mesmo pré-processar as imagens para obter o melhor resultado, nos principais indicadores de performance, como precisão, sensibilidade e pontuação F1.
#
# Por ser um projeto guiado, fique atento quando houver as marcações **Implementação** indica que é necessário realizar alguma implementação em Python no bloco a seguir onde há a inscrição ```##IMPLEMENTAR``` e **Resposta** indica que é esperado uma resposta objetiva relacionado a algum questionamento.
#
# **Cada grupo pode utilizar nas respostas objetivas quaisquer itens necessários que enriqueçam seu ponto vista, como gráficos, fotos e, até mesmo, trechos de código-fonte.**
#
# Pode-se utilizar quantos blocos forem necessários para realizar determinadas implementações ou utilizá-las para justificar as respostas. Não é obrigatório utilizar somente o bloco indicado.
#
# Ao final não se esqueça de subir os arquivos do projeto nas contas do GitHub de cada membro, ou subir na do representante do grupo e os membros realizarem o fork do projeto.
#
# A avaliação terá mais ênfase nos seguintes tópicos de desenvolvimento do projeto:
#
# 1. __Pré-Processamento__
# 2. __Classificação__
# 3. __Performance__
# 4. __Conclusões Finais__

# %% [markdown]
# ## 3.1 Detalhe do problema: a pneunomia
#
# Fonte: [artigo](https://drauziovarella.uol.com.br/doencas-e-sintomas/pneumonia) do Dr. Drauzio Varella.
#
# Pneumonias são infecções que se instalam nos pulmões, órgãos duplos localizados um de cada lado da caixa torácica. Podem acometer a região dos alvéolos pulmonares onde desembocam as ramificações terminais dos brônquios e, às vezes, os interstícios (espaço entre um alvéolo e outro).
#
# Basicamente, pneumonia é provocada pela penetração de um agente infeccioso ou irritante (bactérias, vírus, fungos e por reações alérgicas) no espaço alveolar, onde ocorre a troca gasosa. Esse local deve estar sempre muito limpo, livre de substâncias que possam impedir o contato do ar com o sangue.
#
# Exame clínico, auscultação dos pulmões e radiografias de tórax são recursos essenciais para o diagnóstico de pneumonia.
#
# <p align="center">
#     <img src="imagens/pneumonia.jpeg">
# </p>

# %% [markdown]
# ## 3.2 Diagnóstico por raio-x

# %% [markdown]
# O exame de raio-x traz diferenças em cada tipo de diagnóstico, sendo considerado os seguintes grupos de análise: **normal** (ou controle) onde não há nenhuma condição de infeção, **bacterial pneumonia** (pneumonia bacteriana) que representa a condição de infecção bacteriana e **viral pneumonia** que indica a condição de infecção vira.

# %% [markdown]
# <p align="center">
# <img src="imagens/raiox.png" height="60%" width="60%">
# </p>

# %% [markdown]
# As imagens de controle não são mais brancas ao centro que é onde fica o coração. Já nas imagens com pneumonia é possível notar regiões brancas ao redor dos pulmões, que é como o exame identifica as secreções responsáveis pela infeçcão.
#
# Quando mais regiões brancas ao redor do pulmão mais severa é a inflamação e menos se observa dos detalhes dos pulmões, ficando um pouco esmaecido diante desta condição.

# %% [markdown]
# ## 4.1 Problema
#
# Construir um classificador utilizando _transfer learning_ para identificar as seguintes classes: **controle**, **pneumonia bacteriana** e **pneumonia viral**.
#
# Para construir este classificador, utilize o dataset do [Kaggle Chest Ray Pneumonia](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) e organize os dados de forma a separar em cada uma das classes que já estão definidas no diretório ```raiox```, sendo ```controle``` para as imagens normais (sem inflamação), ```bacteria``` para as imagens de pneumonia bacteriana e ```viral``` para as imagens de pneumonia viral.
#
# Determine a quantidade de imagens a serem treinadas e validadas. Utiliza pelo menos, 100 imagens para cada classe.
#
# Compare os resultados com pelo menos 3 classificadores, obtendo os valores de **precisão (precision)**, **sensibilidade (recall)** e **pontuação F1 (F1 Score)**. No guia abaixo, foi indicado os seguintes modelos: ResNet50, VGG16 e VGG19.
#
# >Importante: a escolha do número de imagens devem ser o suficiente para alcançar o valor de **precisão** mínima de 70%.
#
# A construção do modelo será utilizada o framework Keras.

# %% [markdown]
# **Pergunta**: Qual o número de imagens que foram selecionadas para cada classe?

# %% [markdown]
# **Resposta**: Para o grupo **Controle** 1341 imagens, **Bacteria** 2530 imagens, **Viral** 1345 imagens

# %% [markdown]
# ## 4.2 Componentes obrigatórios
#
# Este projeto requer a instalação dos seguintes componentes, via ```conda install```:
#
# * Keras
# * Tensorflow
# * Pillow
# * Matplotlib

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50
from keras.applications import VGG16, VGG19
from keras.applications import Xception
from keras.applications.xception import preprocess_input
from keras.applications.resnet50 import preprocess_input
from keras.applications.vgg16 import preprocess_input
from keras import Model, layers
from keras.models import load_model, model_from_json

import keras.backend as K

# %% [markdown]
# ## 4.3 Carregando imagens de treinamento e validação
#
# Selecione a melhor divisão entre dados de treinamento e validação. O número deverá ser representado em número fracionário, 5% equivale a 0.05, por exemplo.

# %%
## IMPLEMENTE
divisao_treino_validacao = 0.20

# %%
train_datagen = ImageDataGenerator(validation_split=divisao_treino_validacao)

train_generator = train_datagen.flow_from_directory(
    "raiox/",
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="training")
# Out:
# Found 4173 images belonging to 3 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    "raiox/",
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="validation")
# Out:
# Found 1043 images belonging to 3 classes.

# %%
train_generator.class_indices, val_generator.class_indices
# Out:
# ({'bacteria': 0, 'normal': 1, 'viral': 2},
#  {'bacteria': 0, 'normal': 1, 'viral': 2})

# %% [markdown]
# ## 4.4 Modelos de transfer learning
#
# O Keras já possui classes especializadas para os seguintes modelos de deep-learning treinados com o conjunto de dados [ImageNet](http://www.image-net.org/):
#
# * Xception
# * VGG16
# * VGG19
# * ResNet50
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * DenseNet
# * NASNet
# * MobileNetV2
#
# Mais detalhes, veja na [documentação do Keras](https://keras.io/applications/).

# %% [markdown]
# Para este estudo, vamos utilizar para avaliação as seguintes arquiteturas: RestNet50, VGG15 e VGG19.

# %% [markdown]
# ## 4.5 Indicadores de desempenho
#
# O Keras não possui os indicadores de desempenho como precisão, sensibilidade e pontuação f1 por padrão, portanto precisamos implementar externamente.

# %%
def recall_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ### 4.5.1 Arquitetura ResNet50

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do ResNet50? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %% [markdown]
# A técnica de transfer learning consiste de utilizar o mesmo modelo e treiná-lo para outas imagens. Por tal motivo, excluímos a última camada para modelar com as classes que definimos, ou seja, **controle**, **bacteriana** e **viral**.

# %% [markdown]
# Informe a quantidade de classes a serem classificadas.

# %%
## IMPLEMENTE

qtde_classes = 3

# %%
conv_base = ResNet50(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\keras_applications\resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_8[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           activation_148[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_149[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_150[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, None, None, 2 0           add_49[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_151[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_152[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_153[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_151[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, None, None, 2 0           add_50[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_154[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_155[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_156[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_154[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, None, None, 2 0           add_51[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_157[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_158[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_159[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_157[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, None, None, 5 0           add_52[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_160[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_161[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_162[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_160[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, None, None, 5 0           add_53[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_163[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_164[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_165[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_163[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, None, None, 5 0           add_54[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_166[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_167[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_168[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_166[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, None, None, 5 0           add_55[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_169[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_170[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_171[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_169[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, None, None, 1 0           add_56[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_172[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_173[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_174[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_172[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, None, None, 1 0           add_57[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_175[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_176[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_177[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_175[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, None, None, 1 0           add_58[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_178[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_179[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_180[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_178[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, None, None, 1 0           add_59[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_181[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_182[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_183[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_181[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, None, None, 1 0           add_60[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_184[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_185[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_186[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_184[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, None, None, 1 0           add_61[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524800      activation_187[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_188[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_189[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2099200     activation_187[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, None, None, 2 0           add_62[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_190[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_191[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_192[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, None, None, 2 0           add_63[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_193[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_194[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_195[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  activation_193[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, None, None, 2 0           add_64[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 2048)         0           activation_196[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 128)          262272      global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 3)            387         dense_15[0][0]
# ==================================================================================================
# Total params: 23,850,371
# Trainable params: 262,659
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %% [markdown]
# O número de épocas define quantas vezes o modelo irá treinar e validar o erro, assim ajustando os pesos para melhor convergência.
# Escolha o número adequado de épocas para alcançarmos pelo menos **70% de precisão de validação**.

# %%
## IMPLEMENTE

qtde_epocas = 50

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 40s 8s/step - loss: 0.3795 - precision_score: 0.8379 - recall_score: 0.8125 - f1_score: 0.8248 - val_loss: 1.3488 - val_precision_score: 0.6230 - val_recall_score: 0.6187 - val_f1_score: 0.6208
# Epoch 2/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4306 - precision_score: 0.8527 - recall_score: 0.8250 - f1_score: 0.8385 - val_loss: 1.0259 - val_precision_score: 0.5284 - val_recall_score: 0.5188 - val_f1_score: 0.5235
# Epoch 3/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4664 - precision_score: 0.7920 - recall_score: 0.7437 - f1_score: 0.7667 - val_loss: 1.3135 - val_precision_score: 0.5250 - val_recall_score: 0.5188 - val_f1_score: 0.5218
# Epoch 4/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4507 - precision_score: 0.7800 - recall_score: 0.7437 - f1_score: 0.7612 - val_loss: 1.0512 - val_precision_score: 0.6153 - val_recall_score: 0.6000 - val_f1_score: 0.6075
# Epoch 5/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.5171 - precision_score: 0.7581 - recall_score: 0.7437 - f1_score: 0.7508 - val_loss: 0.9763 - val_precision_score: 0.5989 - val_recall_score: 0.5562 - val_f1_score: 0.5764
# Epoch 6/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4704 - precision_score: 0.7976 - recall_score: 0.7625 - f1_score: 0.7796 - val_loss: 0.8675 - val_precision_score: 0.6030 - val_recall_score: 0.6000 - val_f1_score: 0.6015
# Epoch 7/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.5402 - precision_score: 0.7801 - recall_score: 0.7563 - f1_score: 0.7678 - val_loss: 0.9155 - val_precision_score: 0.5236 - val_recall_score: 0.5092 - val_f1_score: 0.5161
# Epoch 8/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5846 - precision_score: 0.7219 - recall_score: 0.7000 - f1_score: 0.7106 - val_loss: 1.4022 - val_precision_score: 0.4968 - val_recall_score: 0.4938 - val_f1_score: 0.4952
# Epoch 9/50
# 5/5 [==============================] - 41s 8s/step - loss: 0.4623 - precision_score: 0.8030 - recall_score: 0.7750 - f1_score: 0.7886 - val_loss: 1.4397 - val_precision_score: 0.5343 - val_recall_score: 0.5312 - val_f1_score: 0.5327
# Epoch 10/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5083 - precision_score: 0.7885 - recall_score: 0.7625 - f1_score: 0.7752 - val_loss: 0.9388 - val_precision_score: 0.5855 - val_recall_score: 0.5188 - val_f1_score: 0.5499
# Epoch 11/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.5618 - precision_score: 0.7387 - recall_score: 0.7063 - f1_score: 0.7221 - val_loss: 0.9108 - val_precision_score: 0.5691 - val_recall_score: 0.5562 - val_f1_score: 0.5625
# Epoch 12/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4345 - precision_score: 0.8193 - recall_score: 0.7937 - f1_score: 0.8062 - val_loss: 1.0222 - val_precision_score: 0.5567 - val_recall_score: 0.5437 - val_f1_score: 0.5501
# Epoch 13/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.5098 - precision_score: 0.7971 - recall_score: 0.7688 - f1_score: 0.7826 - val_loss: 0.9121 - val_precision_score: 0.4609 - val_recall_score: 0.4250 - val_f1_score: 0.4421
# Epoch 14/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.5102 - precision_score: 0.7924 - recall_score: 0.7760 - f1_score: 0.7840 - val_loss: 1.7954 - val_precision_score: 0.5658 - val_recall_score: 0.5658 - val_f1_score: 0.5658
# Epoch 15/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.6206 - precision_score: 0.8026 - recall_score: 0.7875 - f1_score: 0.7949 - val_loss: 2.0313 - val_precision_score: 0.5125 - val_recall_score: 0.5125 - val_f1_score: 0.5125
# Epoch 16/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.5517 - precision_score: 0.8143 - recall_score: 0.8000 - f1_score: 0.8070 - val_loss: 0.9443 - val_precision_score: 0.6362 - val_recall_score: 0.6125 - val_f1_score: 0.6240
# Epoch 17/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5898 - precision_score: 0.7642 - recall_score: 0.7312 - f1_score: 0.7471 - val_loss: 1.2837 - val_precision_score: 0.5319 - val_recall_score: 0.5250 - val_f1_score: 0.5284
# Epoch 18/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.4857 - precision_score: 0.7968 - recall_score: 0.7688 - f1_score: 0.7823 - val_loss: 1.4365 - val_precision_score: 0.5134 - val_recall_score: 0.4875 - val_f1_score: 0.5000
# Epoch 19/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.3931 - precision_score: 0.8454 - recall_score: 0.8250 - f1_score: 0.8349 - val_loss: 1.0071 - val_precision_score: 0.5563 - val_recall_score: 0.5312 - val_f1_score: 0.5435
# Epoch 20/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.4668 - precision_score: 0.8238 - recall_score: 0.7937 - f1_score: 0.8082 - val_loss: 1.6056 - val_precision_score: 0.4962 - val_recall_score: 0.4908 - val_f1_score: 0.4934
# Epoch 21/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4355 - precision_score: 0.8338 - recall_score: 0.8125 - f1_score: 0.8229 - val_loss: 1.5307 - val_precision_score: 0.4191 - val_recall_score: 0.4000 - val_f1_score: 0.4093
# Epoch 22/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4219 - precision_score: 0.8501 - recall_score: 0.8188 - f1_score: 0.8341 - val_loss: 1.0698 - val_precision_score: 0.6077 - val_recall_score: 0.6000 - val_f1_score: 0.6038
# Epoch 23/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4833 - precision_score: 0.7860 - recall_score: 0.7563 - f1_score: 0.7708 - val_loss: 0.9772 - val_precision_score: 0.5411 - val_recall_score: 0.5312 - val_f1_score: 0.5361
# Epoch 24/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3686 - precision_score: 0.8598 - recall_score: 0.8438 - f1_score: 0.8516 - val_loss: 1.3617 - val_precision_score: 0.6454 - val_recall_score: 0.6125 - val_f1_score: 0.6283
# Epoch 25/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3501 - precision_score: 0.8669 - recall_score: 0.8562 - f1_score: 0.8615 - val_loss: 1.0682 - val_precision_score: 0.6267 - val_recall_score: 0.6187 - val_f1_score: 0.6226
# Epoch 26/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.4138 - precision_score: 0.8398 - recall_score: 0.8250 - f1_score: 0.8322 - val_loss: 1.0231 - val_precision_score: 0.5655 - val_recall_score: 0.5562 - val_f1_score: 0.5608
# Epoch 27/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.3943 - precision_score: 0.8440 - recall_score: 0.8125 - f1_score: 0.8278 - val_loss: 0.9285 - val_precision_score: 0.5956 - val_recall_score: 0.5345 - val_f1_score: 0.5631
# Epoch 28/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3559 - precision_score: 0.8427 - recall_score: 0.8375 - f1_score: 0.8401 - val_loss: 0.5741 - val_precision_score: 0.6902 - val_recall_score: 0.6687 - val_f1_score: 0.6792
# Epoch 29/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3579 - precision_score: 0.8625 - recall_score: 0.8625 - f1_score: 0.8625 - val_loss: 1.0895 - val_precision_score: 0.5782 - val_recall_score: 0.5750 - val_f1_score: 0.5766
# Epoch 30/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.3815 - precision_score: 0.8234 - recall_score: 0.8000 - f1_score: 0.8114 - val_loss: 1.3733 - val_precision_score: 0.4850 - val_recall_score: 0.4625 - val_f1_score: 0.4732
# Epoch 31/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4369 - precision_score: 0.8203 - recall_score: 0.8000 - f1_score: 0.8099 - val_loss: 0.6890 - val_precision_score: 0.6923 - val_recall_score: 0.6625 - val_f1_score: 0.6770
# Epoch 32/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.4244 - precision_score: 0.8236 - recall_score: 0.8125 - f1_score: 0.8180 - val_loss: 0.6240 - val_precision_score: 0.6763 - val_recall_score: 0.6500 - val_f1_score: 0.6627
# Epoch 33/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.3844 - precision_score: 0.8397 - recall_score: 0.8188 - f1_score: 0.8289 - val_loss: 1.9081 - val_precision_score: 0.4576 - val_recall_score: 0.4530 - val_f1_score: 0.4552
# Epoch 34/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4055 - precision_score: 0.8301 - recall_score: 0.8000 - f1_score: 0.8145 - val_loss: 1.2160 - val_precision_score: 0.6559 - val_recall_score: 0.6438 - val_f1_score: 0.6497
# Epoch 35/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3447 - precision_score: 0.8588 - recall_score: 0.8375 - f1_score: 0.8479 - val_loss: 1.1809 - val_precision_score: 0.5688 - val_recall_score: 0.5688 - val_f1_score: 0.5687
# Epoch 36/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.4344 - precision_score: 0.8169 - recall_score: 0.8062 - f1_score: 0.8115 - val_loss: 1.3470 - val_precision_score: 0.6019 - val_recall_score: 0.5875 - val_f1_score: 0.5945
# Epoch 37/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4355 - precision_score: 0.8339 - recall_score: 0.8125 - f1_score: 0.8230 - val_loss: 0.5172 - val_precision_score: 0.6972 - val_recall_score: 0.6750 - val_f1_score: 0.6857
# Epoch 38/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.4331 - precision_score: 0.8516 - recall_score: 0.8250 - f1_score: 0.8381 - val_loss: 0.8784 - val_precision_score: 0.6926 - val_recall_score: 0.6250 - val_f1_score: 0.6567
# Epoch 39/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.4962 - precision_score: 0.8078 - recall_score: 0.7875 - f1_score: 0.7972 - val_loss: 0.9791 - val_precision_score: 0.5698 - val_recall_score: 0.5437 - val_f1_score: 0.5562
# Epoch 40/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.4734 - precision_score: 0.8220 - recall_score: 0.8062 - f1_score: 0.8140 - val_loss: 0.9088 - val_precision_score: 0.6805 - val_recall_score: 0.6365 - val_f1_score: 0.6567
# Epoch 41/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4204 - precision_score: 0.7710 - recall_score: 0.7563 - f1_score: 0.7635 - val_loss: 0.6852 - val_precision_score: 0.7326 - val_recall_score: 0.6625 - val_f1_score: 0.6948
# Epoch 42/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.4730 - precision_score: 0.8125 - recall_score: 0.7875 - f1_score: 0.7997 - val_loss: 0.9329 - val_precision_score: 0.5691 - val_recall_score: 0.5063 - val_f1_score: 0.5351
# Epoch 43/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3838 - precision_score: 0.8592 - recall_score: 0.8438 - f1_score: 0.8513 - val_loss: 1.2132 - val_precision_score: 0.5682 - val_recall_score: 0.5562 - val_f1_score: 0.5621
# Epoch 44/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3760 - precision_score: 0.8589 - recall_score: 0.8375 - f1_score: 0.8480 - val_loss: 0.8705 - val_precision_score: 0.6356 - val_recall_score: 0.5625 - val_f1_score: 0.5964
# Epoch 45/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.3822 - precision_score: 0.8398 - recall_score: 0.8188 - f1_score: 0.8290 - val_loss: 0.6883 - val_precision_score: 0.6144 - val_recall_score: 0.5938 - val_f1_score: 0.6037
# Epoch 46/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4220 - precision_score: 0.8014 - recall_score: 0.7875 - f1_score: 0.7943 - val_loss: 1.5867 - val_precision_score: 0.6103 - val_recall_score: 0.5813 - val_f1_score: 0.5951
# Epoch 47/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.3772 - precision_score: 0.8854 - recall_score: 0.8687 - f1_score: 0.8769 - val_loss: 0.6454 - val_precision_score: 0.6259 - val_recall_score: 0.6033 - val_f1_score: 0.6143
# Epoch 48/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.3638 - precision_score: 0.8501 - recall_score: 0.8346 - f1_score: 0.8423 - val_loss: 1.4019 - val_precision_score: 0.5000 - val_recall_score: 0.5000 - val_f1_score: 0.5000
# Epoch 49/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4202 - precision_score: 0.8294 - recall_score: 0.8188 - f1_score: 0.8240 - val_loss: 0.5763 - val_precision_score: 0.5773 - val_recall_score: 0.5625 - val_f1_score: 0.5697
# Epoch 50/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3799 - precision_score: 0.8717 - recall_score: 0.8438 - f1_score: 0.8574 - val_loss: 0.6777 - val_precision_score: 0.6506 - val_recall_score: 0.6187 - val_f1_score: 0.6341

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:O valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 65,06%, 61,87% e 63,41%.

# %% [markdown]
# ### 4.5.2 Arquitetura VGG16

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG16? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %%
conv_base = VGG16(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_9 ( (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 14,780,739
# Trainable params: 66,051
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 34s 7s/step - loss: 3.7328 - precision_score: 0.3524 - recall_score: 0.3438 - f1_score: 0.3479 - val_loss: 1.6432 - val_precision_score: 0.4375 - val_recall_score: 0.4375 - val_f1_score: 0.4375
# Epoch 2/50
# 5/5 [==============================] - 32s 6s/step - loss: 1.5556 - precision_score: 0.5331 - recall_score: 0.5111 - f1_score: 0.5217 - val_loss: 0.7941 - val_precision_score: 0.6029 - val_recall_score: 0.5625 - val_f1_score: 0.5818
# Epoch 3/50
# 5/5 [==============================] - 35s 7s/step - loss: 1.1773 - precision_score: 0.6649 - recall_score: 0.6438 - f1_score: 0.6540 - val_loss: 0.8983 - val_precision_score: 0.7214 - val_recall_score: 0.7125 - val_f1_score: 0.7169
# Epoch 4/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.8343 - precision_score: 0.7045 - recall_score: 0.6875 - f1_score: 0.6958 - val_loss: 1.1523 - val_precision_score: 0.6658 - val_recall_score: 0.6500 - val_f1_score: 0.6577
# Epoch 5/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.8492 - precision_score: 0.7220 - recall_score: 0.7125 - f1_score: 0.7172 - val_loss: 0.7342 - val_precision_score: 0.7443 - val_recall_score: 0.7125 - val_f1_score: 0.7280
# Epoch 6/50
# 5/5 [==============================] - 37s 7s/step - loss: 1.0732 - precision_score: 0.6781 - recall_score: 0.6500 - f1_score: 0.6635 - val_loss: 0.7889 - val_precision_score: 0.6987 - val_recall_score: 0.6750 - val_f1_score: 0.6865
# Epoch 7/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.8590 - precision_score: 0.7247 - recall_score: 0.7063 - f1_score: 0.7151 - val_loss: 0.5068 - val_precision_score: 0.6597 - val_recall_score: 0.6533 - val_f1_score: 0.6564
# Epoch 8/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.9035 - precision_score: 0.6618 - recall_score: 0.6438 - f1_score: 0.6526 - val_loss: 0.9212 - val_precision_score: 0.7208 - val_recall_score: 0.7125 - val_f1_score: 0.7165
# Epoch 9/50
# 5/5 [==============================] - 41s 8s/step - loss: 0.8034 - precision_score: 0.6758 - recall_score: 0.6625 - f1_score: 0.6690 - val_loss: 0.8560 - val_precision_score: 0.6958 - val_recall_score: 0.6875 - val_f1_score: 0.6916
# Epoch 10/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.6922 - precision_score: 0.7556 - recall_score: 0.7188 - f1_score: 0.7364 - val_loss: 0.7316 - val_precision_score: 0.6704 - val_recall_score: 0.6625 - val_f1_score: 0.6664
# Epoch 11/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.8942 - precision_score: 0.7304 - recall_score: 0.7000 - f1_score: 0.7144 - val_loss: 0.7890 - val_precision_score: 0.7034 - val_recall_score: 0.6750 - val_f1_score: 0.6887
# Epoch 12/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.6863 - precision_score: 0.8060 - recall_score: 0.7500 - f1_score: 0.7765 - val_loss: 0.4099 - val_precision_score: 0.7928 - val_recall_score: 0.7625 - val_f1_score: 0.7771
# Epoch 13/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.7131 - precision_score: 0.7733 - recall_score: 0.7625 - f1_score: 0.7677 - val_loss: 1.4427 - val_precision_score: 0.6651 - val_recall_score: 0.6438 - val_f1_score: 0.6541
# Epoch 14/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.6892 - precision_score: 0.7376 - recall_score: 0.7188 - f1_score: 0.7280 - val_loss: 0.9500 - val_precision_score: 0.6775 - val_recall_score: 0.6641 - val_f1_score: 0.6707
# Epoch 15/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.6044 - precision_score: 0.7738 - recall_score: 0.7625 - f1_score: 0.7681 - val_loss: 0.5792 - val_precision_score: 0.8024 - val_recall_score: 0.7812 - val_f1_score: 0.7916
# Epoch 16/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.7125 - precision_score: 0.7367 - recall_score: 0.7312 - f1_score: 0.7339 - val_loss: 0.7051 - val_precision_score: 0.6253 - val_recall_score: 0.6062 - val_f1_score: 0.6154
# Epoch 17/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.7311 - precision_score: 0.7434 - recall_score: 0.7250 - f1_score: 0.7340 - val_loss: 1.3296 - val_precision_score: 0.7034 - val_recall_score: 0.7000 - val_f1_score: 0.7017
# Epoch 18/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.9016 - precision_score: 0.7163 - recall_score: 0.7125 - f1_score: 0.7144 - val_loss: 0.8078 - val_precision_score: 0.6389 - val_recall_score: 0.6313 - val_f1_score: 0.6350
# Epoch 19/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.7255 - precision_score: 0.7228 - recall_score: 0.7125 - f1_score: 0.7176 - val_loss: 0.9009 - val_precision_score: 0.7091 - val_recall_score: 0.7000 - val_f1_score: 0.7045
# Epoch 20/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.7870 - precision_score: 0.7671 - recall_score: 0.7625 - f1_score: 0.7648 - val_loss: 0.3903 - val_precision_score: 0.7212 - val_recall_score: 0.7122 - val_f1_score: 0.7166
# Epoch 21/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.6068 - precision_score: 0.7532 - recall_score: 0.7437 - f1_score: 0.7484 - val_loss: 0.7153 - val_precision_score: 0.7130 - val_recall_score: 0.7000 - val_f1_score: 0.7063
# Epoch 22/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.6308 - precision_score: 0.7410 - recall_score: 0.7188 - f1_score: 0.7295 - val_loss: 0.8229 - val_precision_score: 0.7063 - val_recall_score: 0.6750 - val_f1_score: 0.6902
# Epoch 23/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.6883 - precision_score: 0.7186 - recall_score: 0.6938 - f1_score: 0.7056 - val_loss: 0.2893 - val_precision_score: 0.7836 - val_recall_score: 0.7500 - val_f1_score: 0.7663
# Epoch 24/50
# 5/5 [==============================] - 40s 8s/step - loss: 0.7507 - precision_score: 0.7433 - recall_score: 0.7250 - f1_score: 0.7340 - val_loss: 0.8991 - val_precision_score: 0.6748 - val_recall_score: 0.6500 - val_f1_score: 0.6622
# Epoch 25/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.6328 - precision_score: 0.7515 - recall_score: 0.7312 - f1_score: 0.7409 - val_loss: 0.5595 - val_precision_score: 0.7406 - val_recall_score: 0.7125 - val_f1_score: 0.7263
# Epoch 26/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.6865 - precision_score: 0.7097 - recall_score: 0.6875 - f1_score: 0.6984 - val_loss: 0.9570 - val_precision_score: 0.7130 - val_recall_score: 0.7000 - val_f1_score: 0.7063
# Epoch 27/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.4508 - precision_score: 0.8390 - recall_score: 0.8062 - f1_score: 0.8221 - val_loss: 0.5984 - val_precision_score: 0.7535 - val_recall_score: 0.7224 - val_f1_score: 0.7373
# Epoch 28/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.4876 - precision_score: 0.8067 - recall_score: 0.7812 - f1_score: 0.7936 - val_loss: 1.0431 - val_precision_score: 0.7110 - val_recall_score: 0.6875 - val_f1_score: 0.6988
# Epoch 29/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.5560 - precision_score: 0.7892 - recall_score: 0.7688 - f1_score: 0.7788 - val_loss: 0.9265 - val_precision_score: 0.7038 - val_recall_score: 0.6812 - val_f1_score: 0.6922
# Epoch 30/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5815 - precision_score: 0.7336 - recall_score: 0.7063 - f1_score: 0.7194 - val_loss: 0.8080 - val_precision_score: 0.7589 - val_recall_score: 0.7437 - val_f1_score: 0.7512
# Epoch 31/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5311 - precision_score: 0.7804 - recall_score: 0.7563 - f1_score: 0.7680 - val_loss: 0.6102 - val_precision_score: 0.7700 - val_recall_score: 0.7563 - val_f1_score: 0.7630
# Epoch 32/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.6062 - precision_score: 0.7216 - recall_score: 0.7000 - f1_score: 0.7102 - val_loss: 0.5293 - val_precision_score: 0.7399 - val_recall_score: 0.7250 - val_f1_score: 0.7323
# Epoch 33/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.4836 - precision_score: 0.7712 - recall_score: 0.7375 - f1_score: 0.7538 - val_loss: 0.1631 - val_precision_score: 0.8310 - val_recall_score: 0.8164 - val_f1_score: 0.8236
# Epoch 34/50
# 5/5 [==============================] - 40s 8s/step - loss: 0.3953 - precision_score: 0.8155 - recall_score: 0.8000 - f1_score: 0.8076 - val_loss: 0.8261 - val_precision_score: 0.6462 - val_recall_score: 0.6375 - val_f1_score: 0.6418
# Epoch 35/50
# 5/5 [==============================] - 43s 9s/step - loss: 0.4470 - precision_score: 0.8100 - recall_score: 0.8000 - f1_score: 0.8048 - val_loss: 0.5315 - val_precision_score: 0.7620 - val_recall_score: 0.7375 - val_f1_score: 0.7493
# Epoch 36/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.5362 - precision_score: 0.8272 - recall_score: 0.8125 - f1_score: 0.8197 - val_loss: 0.5546 - val_precision_score: 0.7316 - val_recall_score: 0.7125 - val_f1_score: 0.7218
# Epoch 37/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4849 - precision_score: 0.8355 - recall_score: 0.8250 - f1_score: 0.8302 - val_loss: 0.9735 - val_precision_score: 0.7625 - val_recall_score: 0.7437 - val_f1_score: 0.7525
# Epoch 38/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3977 - precision_score: 0.8347 - recall_score: 0.8188 - f1_score: 0.8266 - val_loss: 0.5201 - val_precision_score: 0.7845 - val_recall_score: 0.7500 - val_f1_score: 0.7667
# Epoch 39/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.6659 - precision_score: 0.6998 - recall_score: 0.6875 - f1_score: 0.6933 - val_loss: 0.6528 - val_precision_score: 0.7718 - val_recall_score: 0.7625 - val_f1_score: 0.7671
# Epoch 40/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.5232 - precision_score: 0.7767 - recall_score: 0.7563 - f1_score: 0.7663 - val_loss: 0.7154 - val_precision_score: 0.7873 - val_recall_score: 0.7641 - val_f1_score: 0.7754
# Epoch 41/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.3605 - precision_score: 0.8669 - recall_score: 0.8500 - f1_score: 0.8583 - val_loss: 0.8526 - val_precision_score: 0.7732 - val_recall_score: 0.7250 - val_f1_score: 0.7481
# Epoch 42/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.6548 - precision_score: 0.7266 - recall_score: 0.7125 - f1_score: 0.7194 - val_loss: 0.5902 - val_precision_score: 0.8104 - val_recall_score: 0.8000 - val_f1_score: 0.8050
# Epoch 43/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5108 - precision_score: 0.7739 - recall_score: 0.7500 - f1_score: 0.7617 - val_loss: 0.6498 - val_precision_score: 0.6690 - val_recall_score: 0.6562 - val_f1_score: 0.6625
# Epoch 44/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.6616 - precision_score: 0.7645 - recall_score: 0.7500 - f1_score: 0.7571 - val_loss: 0.4932 - val_precision_score: 0.7532 - val_recall_score: 0.7437 - val_f1_score: 0.7484
# Epoch 45/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5248 - precision_score: 0.8119 - recall_score: 0.7937 - f1_score: 0.8025 - val_loss: 0.5811 - val_precision_score: 0.7162 - val_recall_score: 0.6938 - val_f1_score: 0.7046
# Epoch 46/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.4614 - precision_score: 0.7769 - recall_score: 0.7625 - f1_score: 0.7695 - val_loss: 0.5109 - val_precision_score: 0.7287 - val_recall_score: 0.7063 - val_f1_score: 0.7171
# Epoch 47/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.5290 - precision_score: 0.7701 - recall_score: 0.7563 - f1_score: 0.7630 - val_loss: 0.5176 - val_precision_score: 0.7688 - val_recall_score: 0.7224 - val_f1_score: 0.7446
# Epoch 48/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5711 - precision_score: 0.7677 - recall_score: 0.7437 - f1_score: 0.7556 - val_loss: 0.6447 - val_precision_score: 0.7729 - val_recall_score: 0.7437 - val_f1_score: 0.7579
# Epoch 49/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.4626 - precision_score: 0.8333 - recall_score: 0.8125 - f1_score: 0.8225 - val_loss: 0.6104 - val_precision_score: 0.6891 - val_recall_score: 0.6812 - val_f1_score: 0.6851
# Epoch 50/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.5836 - precision_score: 0.7324 - recall_score: 0.7010 - f1_score: 0.7160 - val_loss: 0.5409 - val_precision_score: 0.7389 - val_recall_score: 0.7125 - val_f1_score: 0.7250

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:O valor de precisão, sensibilidade e pontuação de validação são, respectivamente,73,89%, 71,25% e 72,50%.

# %% [markdown]
# ### 4.5.3 Arquitetura VGG19

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG19? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %%
conv_base = VGG19(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_average_pooling2d_10  (None, 512)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 20,090,435
# Trainable params: 66,051
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit_generator(generator=train_generator, 
                              epochs=qtde_epocas, 
                              validation_steps=5, 
                              steps_per_epoch=5, 
                              validation_data=val_generator)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 45s 9s/step - loss: 2.9615 - precision_score: 0.4875 - recall_score: 0.4875 - f1_score: 0.4875 - val_loss: 1.7733 - val_precision_score: 0.5510 - val_recall_score: 0.5063 - val_f1_score: 0.5277
# Epoch 2/50
# 5/5 [==============================] - 46s 9s/step - loss: 1.4043 - precision_score: 0.5512 - recall_score: 0.5312 - f1_score: 0.5409 - val_loss: 1.0470 - val_precision_score: 0.5281 - val_recall_score: 0.4875 - val_f1_score: 0.5065
# Epoch 3/50
# 5/5 [==============================] - 46s 9s/step - loss: 1.1589 - precision_score: 0.6654 - recall_score: 0.6375 - f1_score: 0.6508 - val_loss: 1.5156 - val_precision_score: 0.5844 - val_recall_score: 0.5688 - val_f1_score: 0.5764
# Epoch 4/50
# 5/5 [==============================] - 46s 9s/step - loss: 1.0875 - precision_score: 0.6275 - recall_score: 0.6062 - f1_score: 0.6165 - val_loss: 1.1208 - val_precision_score: 0.6380 - val_recall_score: 0.6250 - val_f1_score: 0.6313
# Epoch 5/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.8629 - precision_score: 0.6429 - recall_score: 0.6313 - f1_score: 0.6370 - val_loss: 0.5679 - val_precision_score: 0.6813 - val_recall_score: 0.6687 - val_f1_score: 0.6749
# Epoch 6/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.6918 - precision_score: 0.7290 - recall_score: 0.7250 - f1_score: 0.7270 - val_loss: 0.9120 - val_precision_score: 0.7811 - val_recall_score: 0.7563 - val_f1_score: 0.7683
# Epoch 7/50
# 5/5 [==============================] - 45s 9s/step - loss: 0.9880 - precision_score: 0.6966 - recall_score: 0.6760 - f1_score: 0.6860 - val_loss: 0.6316 - val_precision_score: 0.7131 - val_recall_score: 0.6951 - val_f1_score: 0.7039
# Epoch 8/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.8882 - precision_score: 0.6792 - recall_score: 0.6625 - f1_score: 0.6705 - val_loss: 0.8725 - val_precision_score: 0.6687 - val_recall_score: 0.6687 - val_f1_score: 0.6687
# Epoch 9/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.6318 - precision_score: 0.7671 - recall_score: 0.7625 - f1_score: 0.7648 - val_loss: 0.7553 - val_precision_score: 0.7718 - val_recall_score: 0.7625 - val_f1_score: 0.7671
# Epoch 10/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.7844 - precision_score: 0.7234 - recall_score: 0.6875 - f1_score: 0.7050 - val_loss: 0.5145 - val_precision_score: 0.7832 - val_recall_score: 0.7688 - val_f1_score: 0.7758
# Epoch 11/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.6889 - precision_score: 0.8080 - recall_score: 0.7937 - f1_score: 0.8005 - val_loss: 0.5534 - val_precision_score: 0.7233 - val_recall_score: 0.7000 - val_f1_score: 0.7114
# Epoch 12/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.7734 - precision_score: 0.6553 - recall_score: 0.6313 - f1_score: 0.6428 - val_loss: 0.8320 - val_precision_score: 0.6158 - val_recall_score: 0.5938 - val_f1_score: 0.6045
# Epoch 13/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.7750 - precision_score: 0.7213 - recall_score: 0.7063 - f1_score: 0.7136 - val_loss: 1.0778 - val_precision_score: 0.7234 - val_recall_score: 0.7188 - val_f1_score: 0.7210
# Epoch 14/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.8124 - precision_score: 0.6996 - recall_score: 0.6812 - f1_score: 0.6903 - val_loss: 0.7443 - val_precision_score: 0.6546 - val_recall_score: 0.6451 - val_f1_score: 0.6497
# Epoch 15/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.6680 - precision_score: 0.7345 - recall_score: 0.7063 - f1_score: 0.7198 - val_loss: 0.3638 - val_precision_score: 0.7772 - val_recall_score: 0.7500 - val_f1_score: 0.7629
# Epoch 16/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.6415 - precision_score: 0.7842 - recall_score: 0.7688 - f1_score: 0.7763 - val_loss: 0.8137 - val_precision_score: 0.6895 - val_recall_score: 0.6625 - val_f1_score: 0.6755
# Epoch 17/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.8223 - precision_score: 0.6978 - recall_score: 0.6812 - f1_score: 0.6892 - val_loss: 0.8136 - val_precision_score: 0.6947 - val_recall_score: 0.6750 - val_f1_score: 0.6845
# Epoch 18/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.6010 - precision_score: 0.7796 - recall_score: 0.7750 - f1_score: 0.7773 - val_loss: 0.4398 - val_precision_score: 0.7714 - val_recall_score: 0.7563 - val_f1_score: 0.7637
# Epoch 19/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.6132 - precision_score: 0.7829 - recall_score: 0.7625 - f1_score: 0.7725 - val_loss: 0.7261 - val_precision_score: 0.7374 - val_recall_score: 0.7125 - val_f1_score: 0.7244
# Epoch 20/50
# 5/5 [==============================] - 45s 9s/step - loss: 0.5835 - precision_score: 0.7639 - recall_score: 0.7500 - f1_score: 0.7568 - val_loss: 0.5268 - val_precision_score: 0.7484 - val_recall_score: 0.7201 - val_f1_score: 0.7335
# Epoch 21/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.6370 - precision_score: 0.7439 - recall_score: 0.7250 - f1_score: 0.7342 - val_loss: 0.5286 - val_precision_score: 0.7204 - val_recall_score: 0.7125 - val_f1_score: 0.7164
# Epoch 22/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.7061 - precision_score: 0.7354 - recall_score: 0.7125 - f1_score: 0.7237 - val_loss: 0.8933 - val_precision_score: 0.7762 - val_recall_score: 0.7563 - val_f1_score: 0.7658
# Epoch 23/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.6094 - precision_score: 0.8109 - recall_score: 0.8062 - f1_score: 0.8085 - val_loss: 0.5621 - val_precision_score: 0.7476 - val_recall_score: 0.7375 - val_f1_score: 0.7425
# Epoch 24/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.5197 - precision_score: 0.7701 - recall_score: 0.7563 - f1_score: 0.7630 - val_loss: 0.6070 - val_precision_score: 0.7532 - val_recall_score: 0.7437 - val_f1_score: 0.7484
# Epoch 25/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.4498 - precision_score: 0.8242 - recall_score: 0.7937 - f1_score: 0.8085 - val_loss: 0.5682 - val_precision_score: 0.7659 - val_recall_score: 0.7375 - val_f1_score: 0.7510
# Epoch 26/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.5542 - precision_score: 0.7811 - recall_score: 0.7563 - f1_score: 0.7683 - val_loss: 0.7878 - val_precision_score: 0.7458 - val_recall_score: 0.7312 - val_f1_score: 0.7384
# Epoch 27/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.4319 - precision_score: 0.8395 - recall_score: 0.8188 - f1_score: 0.8290 - val_loss: 0.7113 - val_precision_score: 0.8172 - val_recall_score: 0.7872 - val_f1_score: 0.8018
# Epoch 28/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.5226 - precision_score: 0.7930 - recall_score: 0.7688 - f1_score: 0.7802 - val_loss: 0.4984 - val_precision_score: 0.7516 - val_recall_score: 0.7188 - val_f1_score: 0.7348
# Epoch 29/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.5620 - precision_score: 0.8038 - recall_score: 0.7875 - f1_score: 0.7954 - val_loss: 0.5182 - val_precision_score: 0.6837 - val_recall_score: 0.6750 - val_f1_score: 0.6793
# Epoch 30/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.6139 - precision_score: 0.7440 - recall_score: 0.7250 - f1_score: 0.7343 - val_loss: 0.4584 - val_precision_score: 0.7575 - val_recall_score: 0.7437 - val_f1_score: 0.7505
# Epoch 31/50
# 5/5 [==============================] - 44s 9s/step - loss: 0.4627 - precision_score: 0.8183 - recall_score: 0.7851 - f1_score: 0.8013 - val_loss: 0.6361 - val_precision_score: 0.7498 - val_recall_score: 0.7312 - val_f1_score: 0.7404
# Epoch 32/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.4538 - precision_score: 0.8460 - recall_score: 0.8250 - f1_score: 0.8353 - val_loss: 0.4807 - val_precision_score: 0.7050 - val_recall_score: 0.6875 - val_f1_score: 0.6960
# Epoch 33/50
# 5/5 [==============================] - 45s 9s/step - loss: 0.4796 - precision_score: 0.7899 - recall_score: 0.7750 - f1_score: 0.7823 - val_loss: 0.3859 - val_precision_score: 0.7230 - val_recall_score: 0.7016 - val_f1_score: 0.7119
# Epoch 34/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.3987 - precision_score: 0.8893 - recall_score: 0.8562 - f1_score: 0.8723 - val_loss: 0.5213 - val_precision_score: 0.7363 - val_recall_score: 0.7188 - val_f1_score: 0.7272
# Epoch 35/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.3747 - precision_score: 0.8471 - recall_score: 0.8313 - f1_score: 0.8390 - val_loss: 1.0009 - val_precision_score: 0.7134 - val_recall_score: 0.7000 - val_f1_score: 0.7065
# Epoch 36/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.4268 - precision_score: 0.8425 - recall_score: 0.8375 - f1_score: 0.8400 - val_loss: 0.8846 - val_precision_score: 0.7337 - val_recall_score: 0.7250 - val_f1_score: 0.7292
# Epoch 37/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.4570 - precision_score: 0.8415 - recall_score: 0.8313 - f1_score: 0.8363 - val_loss: 0.6187 - val_precision_score: 0.6774 - val_recall_score: 0.6687 - val_f1_score: 0.6730
# Epoch 38/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.6139 - precision_score: 0.7615 - recall_score: 0.7563 - f1_score: 0.7588 - val_loss: 0.8144 - val_precision_score: 0.7320 - val_recall_score: 0.7063 - val_f1_score: 0.7186
# Epoch 39/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.4722 - precision_score: 0.7711 - recall_score: 0.7563 - f1_score: 0.7635 - val_loss: 0.4238 - val_precision_score: 0.7735 - val_recall_score: 0.7500 - val_f1_score: 0.7615
# Epoch 40/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.4976 - precision_score: 0.8046 - recall_score: 0.8000 - f1_score: 0.8023 - val_loss: 0.6641 - val_precision_score: 0.7503 - val_recall_score: 0.7329 - val_f1_score: 0.7412
# Epoch 41/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.4693 - precision_score: 0.8103 - recall_score: 0.8000 - f1_score: 0.8051 - val_loss: 0.5574 - val_precision_score: 0.7765 - val_recall_score: 0.7188 - val_f1_score: 0.7464
# Epoch 42/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.5808 - precision_score: 0.7917 - recall_score: 0.7812 - f1_score: 0.7864 - val_loss: 0.4494 - val_precision_score: 0.7639 - val_recall_score: 0.7500 - val_f1_score: 0.7568
# Epoch 43/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.4680 - precision_score: 0.8219 - recall_score: 0.8062 - f1_score: 0.8139 - val_loss: 0.8429 - val_precision_score: 0.6690 - val_recall_score: 0.6562 - val_f1_score: 0.6625
# Epoch 44/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.4563 - precision_score: 0.7946 - recall_score: 0.7750 - f1_score: 0.7842 - val_loss: 0.6474 - val_precision_score: 0.7780 - val_recall_score: 0.7688 - val_f1_score: 0.7733
# Epoch 45/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.5397 - precision_score: 0.7624 - recall_score: 0.7437 - f1_score: 0.7528 - val_loss: 0.4088 - val_precision_score: 0.7728 - val_recall_score: 0.7437 - val_f1_score: 0.7577
# Epoch 46/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.4850 - precision_score: 0.8163 - recall_score: 0.8062 - f1_score: 0.8112 - val_loss: 0.4949 - val_precision_score: 0.7522 - val_recall_score: 0.7375 - val_f1_score: 0.7447
# Epoch 47/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.6548 - precision_score: 0.7347 - recall_score: 0.7250 - f1_score: 0.7298 - val_loss: 0.5504 - val_precision_score: 0.7135 - val_recall_score: 0.6970 - val_f1_score: 0.7050
# Epoch 48/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.5750 - precision_score: 0.7111 - recall_score: 0.7063 - f1_score: 0.7086 - val_loss: 0.5716 - val_precision_score: 0.7429 - val_recall_score: 0.7250 - val_f1_score: 0.7337
# Epoch 49/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.5619 - precision_score: 0.7601 - recall_score: 0.7563 - f1_score: 0.7581 - val_loss: 0.7110 - val_precision_score: 0.7381 - val_recall_score: 0.7063 - val_f1_score: 0.7216
# Epoch 50/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.5790 - precision_score: 0.7383 - recall_score: 0.7188 - f1_score: 0.7282 - val_loss: 0.5579 - val_precision_score: 0.7788 - val_recall_score: 0.7688 - val_f1_score: 0.7737

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:O valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 77,88%, 76,88% e 77,37%.

# %% [markdown]
# ## 4.6 Compartivo de arquiteturas
#
# Preencha a tabela abaixo com os valores dos indicadores de performance apresentados.
#
# _O cálculo do F1-Score é dado por 2 * (Precisão * Sensibilidade) / (Precisão + Sensibilidade)._

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | ResNet50 | 65,06 %     | 61,87 %          | 63,41 %     |
# | VGG16    | 73,89 %     | 71,25 %          | 72,50 %     |
# | VGG19    | 77,88 %     | 76,88 %          | 77,37 %     |

# %% [markdown]
# ## 4.7 Conclusões
#
# Analise os resultados da tabela de indicadores do comparativo de arquiteturas e explique os principais motivos pelos quais cada modelo obteve cada resultado.

# %% [markdown]
# **Respota**:

# %% [markdown]
# ## 4.8 Abordagem Extra
#
# Considerando os outros classificadores, escolha outro que ainda não foi utilizado, implemente abaixo. Ao final compare os resultados e explique os resultados.
#
# _Não se esquece de utilizar as importações adequadas para cada modelo.
# A forma de implementação deve respeitar as mesmas condições como valor de split e quantidade de imagens para poder comparar os modelos._

# %%
#IMPLEMENTE

# %% [markdown]
# ### 4.8.1 Conclusões sobre a abordagem extra
#
# Como seu modelo performou em comparação com os demais modelos anteriores? Justifique sua resposta levando em consideração a arquitetura respectiva.

# %% [markdown]
# **Resposta**:
